# %%
# !pip install -q kaggle

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8a9e2a7e-8e1f-486d-b9fa-1ce4e4bbec53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a9e2a7e-8e1f-486d-b9fa-1ce4e4bbec53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ...
# ref                                                     title                                          size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------  --------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# syedanwarafridi/vehicle-sales-data                      Vehicle Sales Data                             19MB  2024-02-21 20:16:17           7409        124  1.0
# tarunrm09/climate-change-indicators                     Climate change Indicators                      34KB  2024-02-22 08:53:54           3682         92  1.0
# mikhail1681/walmart-sales                               Walmart Sales                                 122KB  2024-02-13 17:35:56           5801         87  1.0
# nbroad/gemma-rewrite-nbroad                             gemma-rewrite-nbroad                            8MB  2024-03-03 04:52:39            308         45  1.0
# ...

# %%
! kaggle datasets download -d uwrfkaggler/ravdess-emotional-speech-audio
# Out:
# ...
#  98% 421M/429M [00:01<00:00, 236MB/s]
# 100% 429M/429M [00:01<00:00, 262MB/s]

# %%
! unzip '/content/ravdess-emotional-speech-audio.zip'
# Out:
# Archive:  /content/ravdess-emotional-speech-audio.zip
#   inflating: Actor_01/03-01-01-01-01-01-01.wav
#   inflating: Actor_01/03-01-01-01-01-02-01.wav
#   inflating: Actor_01/03-01-01-01-02-01-01.wav
#   inflating: Actor_01/03-01-01-01-02-02-01.wav
#   inflating: Actor_01/03-01-02-01-01-01-01.wav
#   inflating: Actor_01/03-01-02-01-01-02-01.wav
#   inflating: Actor_01/03-01-02-01-02-01-01.wav
#   inflating: Actor_01/03-01-02-01-02-02-01.wav
#   inflating: Actor_01/03-01-02-02-01-01-01.wav
#   inflating: Actor_01/03-01-02-02-01-02-01.wav
#   inflating: Actor_01/03-01-02-02-02-01-01.wav
#   inflating: Actor_01/03-01-02-02-02-02-01.wav
#   inflating: Actor_01/03-01-03-01-01-01-01.wav
#   inflating: Actor_01/03-01-03-01-01-02-01.wav
#   inflating: Actor_01/03-01-03-01-02-01-01.wav
#   inflating: Actor_01/03-01-03-01-02-02-01.wav
#   inflating: Actor_01/03-01-03-02-01-01-01.wav
#   inflating: Actor_01/03-01-03-02-01-02-01.wav
#   inflating: Actor_01/03-01-03-02-02-01-01.wav
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import librosa

# %%
import librosa.display

# %%
from glob import glob

# %%
import IPython.display as ipd

# %%
y,sr = librosa.load('/content/Actor_01/03-01-02-01-01-02-01.wav')

# %%
ipd.Audio(y, rate=sr )
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y
# Out:
# array([ 3.2808437e-13,  1.5257094e-13,  4.6160536e-13, ...,
#        -9.9160064e-12,  3.4260858e-12,  0.0000000e+00], dtype=float32)

# %%
sr
# Out:
# 22050

# %%
audio, sample_rate = librosa.load('/content/Actor_01/03-01-02-01-01-02-01.wav')

plt.figure(figsize=(10, 4))
plt.plot(audio)
plt.xlabel('Time (samples)')
plt.ylabel('Amplitude')
plt.title('Audio Signal')
plt.show()

# %%
spectrogram = librosa.feature.melspectrogram(y=y, sr=sr)

# Convert to decibels
spectrogram_db = librosa.power_to_db(spectrogram, ref=np.max)

# Plot the spectrogram
plt.figure(figsize=(10, 4))
librosa.display.specshow(spectrogram_db, x_axis='time', y_axis='mel', sr=sr)
plt.colorbar(format='%+2.0f dB')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.title('Spectrogram')
plt.show()
